# %% [markdown]
# A model to predict hotel cancellations with a binary classifier.

# %%
# Setup plotting
import matplotlib.pyplot as plt
# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('animation', html='html5')

# %% [markdown]
# ### Data

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer

hotel = pd.read_csv('data/hotel.csv')

X = hotel.copy()
y = X.pop('is_canceled')

X['arrival_date_month'] = \
    X['arrival_date_month'].map(
        {'January':1, 'February': 2, 'March':3,
         'April':4, 'May':5, 'June':6, 'July':7,
         'August':8, 'September':9, 'October':10,
         'November':11, 'December':12}
    )

features_num = [
    "lead_time", "arrival_date_week_number",
    "arrival_date_day_of_month", "stays_in_weekend_nights",
    "stays_in_week_nights", "adults", "children", "babies",
    "is_repeated_guest", "previous_cancellations",
    "previous_bookings_not_canceled", "required_car_parking_spaces",
    "total_of_special_requests", "adr",
]
features_cat = [
    "hotel", "arrival_date_month", "meal",
    "market_segment", "distribution_channel",
    "reserved_room_type", "deposit_type", "customer_type",
]

transformer_num = make_pipeline(
    SimpleImputer(strategy="constant"), # there are a few missing values
    StandardScaler(),
)
transformer_cat = make_pipeline(
    SimpleImputer(strategy="constant", fill_value="NA"),
    OneHotEncoder(handle_unknown='ignore'),
)

preprocessor = make_column_transformer(
    (transformer_num, features_num),
    (transformer_cat, features_cat),
)

# stratify - make sure classes are evenlly represented across splits
X_train, X_valid, y_train, y_valid = \
    train_test_split(X, y, stratify=y, train_size=0.75)

X_train = preprocessor.fit_transform(X_train)
X_valid = preprocessor.transform(X_valid)

input_shape = [X_train.shape[1]]

# %% [markdown]
# ### Model
#
# With both batch-normalization and dropout.

# %%
from tensorflow import keras
from keras import layers
from keras import callbacks


model = keras.Sequential([
    layers.BatchNormalization(input_shape=input_shape),
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(1, activation='sigmoid'),
])

# %% [markdown]
# ### Optimizer, Loss, Metric

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['binary_accuracy'],
)

# %% [markdown]
# ### Training the Model

# %%
early_stopping = keras.callbacks.EarlyStopping(
    patience=5,
    min_delta=0.001,
    restore_best_weights=True,
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=200,
    callbacks=[early_stopping],
)

history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot(title="Cross-entropy")
history_df.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot(title="Accuracy")
# Out:
# 175/175 [==============================] - 1s 5ms/step - loss: 0.4215 - binary_accuracy: 0.8020 - val_loss: 0.4060 - val_binary_accuracy: 0.8117
# Epoch 3/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.4091 - binary_accuracy: 0.8080 - val_loss: 0.3986 - val_binary_accuracy: 0.8149
# Epoch 4/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.4026 - binary_accuracy: 0.8132 - val_loss: 0.3955 - val_binary_accuracy: 0.8165
# Epoch 5/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3977 - binary_accuracy: 0.8153 - val_loss: 0.3896 - val_binary_accuracy: 0.8191
# Epoch 6/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3914 - binary_accuracy: 0.8179 - val_loss: 0.3878 - val_binary_accuracy: 0.8216
# Epoch 7/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3861 - binary_accuracy: 0.8206 - val_loss: 0.3863 - val_binary_accuracy: 0.8228
# Epoch 8/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3849 - binary_accuracy: 0.8215 - val_loss: 0.3852 - val_binary_accuracy: 0.8235
# Epoch 9/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3815 - binary_accuracy: 0.8242 - val_loss: 0.3835 - val_binary_accuracy: 0.8249
# Epoch 10/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3784 - binary_accuracy: 0.8254 - val_loss: 0.3789 - val_binary_accuracy: 0.8259
# Epoch 11/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3759 - binary_accuracy: 0.8264 - val_loss: 0.3750 - val_binary_accuracy: 0.8282
# Epoch 12/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3722 - binary_accuracy: 0.8277 - val_loss: 0.3784 - val_binary_accuracy: 0.8266
# Epoch 13/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3710 - binary_accuracy: 0.8292 - val_loss: 0.3742 - val_binary_accuracy: 0.8294
# Epoch 14/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3687 - binary_accuracy: 0.8294 - val_loss: 0.3767 - val_binary_accuracy: 0.8265
# Epoch 15/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3667 - binary_accuracy: 0.8302 - val_loss: 0.3726 - val_binary_accuracy: 0.8294
# Epoch 16/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3644 - binary_accuracy: 0.8314 - val_loss: 0.3689 - val_binary_accuracy: 0.8310
# Epoch 17/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3638 - binary_accuracy: 0.8310 - val_loss: 0.3707 - val_binary_accuracy: 0.8279
# Epoch 18/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3622 - binary_accuracy: 0.8323 - val_loss: 0.3688 - val_binary_accuracy: 0.8312
# Epoch 19/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3612 - binary_accuracy: 0.8332 - val_loss: 0.3682 - val_binary_accuracy: 0.8293
# Epoch 20/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3581 - binary_accuracy: 0.8341 - val_loss: 0.3640 - val_binary_accuracy: 0.8318
# Epoch 21/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3580 - binary_accuracy: 0.8350 - val_loss: 0.3681 - val_binary_accuracy: 0.8305
# Epoch 22/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3552 - binary_accuracy: 0.8370 - val_loss: 0.3630 - val_binary_accuracy: 0.8334
# Epoch 23/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3550 - binary_accuracy: 0.8365 - val_loss: 0.3639 - val_binary_accuracy: 0.8320
# Epoch 24/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3531 - binary_accuracy: 0.8380 - val_loss: 0.3625 - val_binary_accuracy: 0.8326
# Epoch 25/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3529 - binary_accuracy: 0.8376 - val_loss: 0.3607 - val_binary_accuracy: 0.8327
# Epoch 26/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3513 - binary_accuracy: 0.8383 - val_loss: 0.3614 - val_binary_accuracy: 0.8324
# Epoch 27/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3493 - binary_accuracy: 0.8380 - val_loss: 0.3659 - val_binary_accuracy: 0.8301
# Epoch 28/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3491 - binary_accuracy: 0.8385 - val_loss: 0.3602 - val_binary_accuracy: 0.8327
# Epoch 29/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3473 - binary_accuracy: 0.8406 - val_loss: 0.3607 - val_binary_accuracy: 0.8330
# Epoch 30/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3466 - binary_accuracy: 0.8402 - val_loss: 0.3588 - val_binary_accuracy: 0.8335
# Epoch 31/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3453 - binary_accuracy: 0.8401 - val_loss: 0.3610 - val_binary_accuracy: 0.8320
# Epoch 32/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3435 - binary_accuracy: 0.8418 - val_loss: 0.3591 - val_binary_accuracy: 0.8346
# Epoch 33/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3426 - binary_accuracy: 0.8419 - val_loss: 0.3593 - val_binary_accuracy: 0.8348
# Epoch 34/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3421 - binary_accuracy: 0.8414 - val_loss: 0.3570 - val_binary_accuracy: 0.8349
# Epoch 35/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3418 - binary_accuracy: 0.8421 - val_loss: 0.3589 - val_binary_accuracy: 0.8335
# Epoch 36/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3412 - binary_accuracy: 0.8432 - val_loss: 0.3563 - val_binary_accuracy: 0.8356
# Epoch 37/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3400 - binary_accuracy: 0.8428 - val_loss: 0.3584 - val_binary_accuracy: 0.8352
# Epoch 38/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3382 - binary_accuracy: 0.8460 - val_loss: 0.3559 - val_binary_accuracy: 0.8359
# Epoch 39/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3382 - binary_accuracy: 0.8445 - val_loss: 0.3573 - val_binary_accuracy: 0.8347
# Epoch 40/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3386 - binary_accuracy: 0.8440 - val_loss: 0.3570 - val_binary_accuracy: 0.8360
# Epoch 41/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3367 - binary_accuracy: 0.8451 - val_loss: 0.3579 - val_binary_accuracy: 0.8357
# Epoch 42/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3350 - binary_accuracy: 0.8451 - val_loss: 0.3564 - val_binary_accuracy: 0.8370
# Epoch 43/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3356 - binary_accuracy: 0.8456 - val_loss: 0.3554 - val_binary_accuracy: 0.8366
# <Axes: title={'center': 'Accuracy'}>

# %% [markdown]
# Though we can see the training loss continuing to fall, the early stopping callback prevented any overfitting. Moreover, the accuracy rose at the same rate as the cross-entropy fell, so it appears that minimizing cross-entropy was a good stand-in. All in all, it looks like this training was a success!
